# %%
import pandas as pd

# %%
df = pd.read_excel('CovidDeaths.xlsx')
df.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.to_csv('CovidDeaths.csv')

# %%
a = pd.read_csv('CovidDeaths.csv')
a.head()
# Out:
#    Unnamed: 0 iso_code continent     location        date  total_cases  \
# 0           0      AFG      Asia  Afghanistan  2020-02-24          1.0
# 1           1      AFG      Asia  Afghanistan  2020-02-25          1.0
# 2           2      AFG      Asia  Afghanistan  2020-02-26          1.0
# 3           3      AFG      Asia  Afghanistan  2020-02-27          1.0
# 4           4      AFG      Asia  Afghanistan  2020-02-28          1.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        1.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# ...

# %%
b = pd.read_excel('CovidVaccinations.xlsx')
b.head()
# Out:
#   iso_code continent     location       date  new_tests  total_tests  \
# 0      AFG      Asia  Afghanistan 2020-02-24        NaN          NaN
# 1      AFG      Asia  Afghanistan 2020-02-25        NaN          NaN
# 2      AFG      Asia  Afghanistan 2020-02-26        NaN          NaN
# 3      AFG      Asia  Afghanistan 2020-02-27        NaN          NaN
# 4      AFG      Asia  Afghanistan 2020-02-28        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  gdp_per_capita  extreme_poverty  \
# ...

# %%
b.to_csv('CovidVaccinations.csv')

# %%
c = pd.read_csv('CovidVaccinations.csv')
c.head()
# Out:
#    Unnamed: 0 iso_code continent     location        date  new_tests  \
# 0           0      AFG      Asia  Afghanistan  2020-02-24        NaN
# 1           1      AFG      Asia  Afghanistan  2020-02-25        NaN
# 2           2      AFG      Asia  Afghanistan  2020-02-26        NaN
# 3           3      AFG      Asia  Afghanistan  2020-02-27        NaN
# 4           4      AFG      Asia  Afghanistan  2020-02-28        NaN
#
#    total_tests  total_tests_per_thousand  new_tests_per_thousand  \
# 0          NaN                       NaN                     NaN
# 1          NaN                       NaN                     NaN
# 2          NaN                       NaN                     NaN
# 3          NaN                       NaN                     NaN
# 4          NaN                       NaN                     NaN
#
#    new_tests_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 0                 NaN  ...        1803.987              NaN
# ...
